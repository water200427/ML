# %% [markdown]
# <a href="https://colab.research.google.com/github/water200427/ML/blob/master/data_remain_only_nums.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # New Section

# %%
df = pd.read_csv('train.csv', index_col=0)

# %% [markdown]
# # New Section

# %%
df.head(10)
# Out:
#     MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# Id                                    ...
# 1           60       RL         65.0  ...        WD        Normal    208500
# 2           20       RL         80.0  ...        WD        Normal    181500
# 3           60       RL         68.0  ...        WD        Normal    223500
# 4           70       RL         60.0  ...        WD       Abnorml    140000
# 5           60       RL         84.0  ...        WD        Normal    250000
# 6           50       RL         85.0  ...        WD        Normal    143000
# 7           20       RL         75.0  ...        WD        Normal    307000
# 8           60       RL          NaN  ...        WD        Normal    200000
# 9           50       RM         51.0  ...        WD       Abnorml    129900
# 10         190       RL         50.0  ...        WD        Normal    118000
#
# [10 rows x 80 columns]

# %% [markdown]
# #NAN處理

# %%
def one_hot_incode(feature):
  labelencoder = LabelEncoder()
  data = labelencoder.fit_transform(df[feature])
  return data

df = pd.read_csv('train.csv', index_col=0)

num = df.isna().sum()
j=-1
for i in num:
  j=j+1
  if i > 35:
    #print(i)
    #print(num.index[j]) 
    df = df.drop(labels=num.index[j], axis='columns')
    # print(num.index[j])
  else:
    df = df.fillna(axis=0,method='ffill') #nan先用上面的補

df
# Out:
#       MSSubClass MSZoning  LotArea  ... SaleType SaleCondition SalePrice
# Id                                  ...
# 1             60       RL     8450  ...       WD        Normal    208500
# 2             20       RL     9600  ...       WD        Normal    181500
# 3             60       RL    11250  ...       WD        Normal    223500
# 4             70       RL     9550  ...       WD       Abnorml    140000
# 5             60       RL    14260  ...       WD        Normal    250000
# ...          ...      ...      ...  ...      ...           ...       ...
# 1456          60       RL     7917  ...       WD        Normal    175000
# 1457          20       RL    13175  ...       WD        Normal    210000
# 1458          70       RL     9042  ...       WD        Normal    266500
# 1459          20       RL     9717  ...       WD        Normal    142125
# 1460          20       RL     9937  ...       WD        Normal    147500
#
# [1460 rows x 64 columns]

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #全數字的Data
# ## df_num_only: 是只有數字的data

# %%
non_num = []
for col in df:
    if df[col].dtypes not in ["float64", "int64"] :
        non_num.append(col)
df_num_only = df.drop(columns=non_num)

# %% [markdown]
# #英文轉數字

# %%
new_df = df.drop(labels=['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 
                     'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
                      'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
                     'GarageArea', 'WoodDeckSF','OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold','YrSold','SalePrice'],axis='columns')

def one_hot_incode(feature):
  labelencoder = LabelEncoder()
  data = labelencoder.fit_transform(df[feature])
  return data

for i in range(len(column_name)):
    #print(i)
    new_df[column_name[i]] = one_hot_incode(column_name[i])

print(new_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-504-8ec12595255b> in <module>()
#       4                      'GarageArea', 'WoodDeckSF','OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold','YrSold','SalePrice'],axis='columns')
#       5
# ----> 6 new_df[col]
#       7 def one_hot_incode(feature):
#       8   labelencoder = LabelEncoder()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SalePrice'

# %%
new_df
# Out:
#      MSZoning Street LotShape  ... PavedDrive SaleType SaleCondition
# Id                             ...
# 1          RL   Pave      Reg  ...          Y       WD        Normal
# 2          RL   Pave      Reg  ...          Y       WD        Normal
# 3          RL   Pave      IR1  ...          Y       WD        Normal
# 4          RL   Pave      IR1  ...          Y       WD       Abnorml
# 5          RL   Pave      IR1  ...          Y       WD        Normal
# ...       ...    ...      ...  ...        ...      ...           ...
# 1456       RL   Pave      Reg  ...          Y       WD        Normal
# 1457       RL   Pave      Reg  ...          Y       WD        Normal
# 1458       RL   Pave      Reg  ...          Y       WD        Normal
# 1459       RL   Pave      Reg  ...          Y       WD        Normal
# 1460       RL   Pave      Reg  ...          Y       WD        Normal
#
# [1460 rows x 29 columns]

# %% [markdown]
# #合併new_df與df_num

# %%
final_df=pd.concat([df_num, new_df],axis=1)
print(final_df)
# Out:
#       MSSubClass  LotArea  OverallQual  ...  PavedDrive  SaleType  SaleCondition
# Id                                      ...
# 1             60     8450            7  ...           Y        WD         Normal
# 2             20     9600            6  ...           Y        WD         Normal
# 3             60    11250            7  ...           Y        WD         Normal
# 4             70     9550            7  ...           Y        WD        Abnorml
# 5             60    14260            8  ...           Y        WD         Normal
# ...          ...      ...          ...  ...         ...       ...            ...
# 1456          60     7917            6  ...           Y        WD         Normal
# 1457          20    13175            6  ...           Y        WD         Normal
# 1458          70     9042            7  ...           Y        WD         Normal
# 1459          20     9717            5  ...           Y        WD         Normal
# 1460          20     9937            5  ...           Y        WD         Normal
#
# [1460 rows x 64 columns]

# %% [markdown]
# #畫關係圖

# %%
#SalePrice Statistics
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#Histogram of 'SalePrice'
sns.distplot(df['SalePrice']);

# %%
#Correlation matrix of df
corr_mat1=new_df.corr()
x,y = plt.subplots(figsize=(15, 10))
sns.heatmap(corr_mat1, vmax=.5, cmap="jet");
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-411-dfb163dd584d> in <module>()
#       2 corr_mat1=new_df.corr()
#       3 x,y = plt.subplots(figsize=(15, 10))
# ----> 4 sns.heatmap(corr_mat1, vmax=.5, cmap="jet");
#
# /usr/local/lib/python3.6/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     536                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 537                           yticklabels, mask)
#     538
#     539     # Add the pcolormesh kwargs here
#
# /usr/local/lib/python3.6/dist-packages/seaborn/matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     163         # Determine good default values for the colormapping
#     164         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 165                                     cmap, center, robust)
#     166
#     167         # Sort out the annotations
#
# /usr/local/lib/python3.6/dist-packages/seaborn/matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     201                 vmin = np.nanpercentile(calc_data, 2)
#     202             else:
# --> 203                 vmin = np.nanmin(calc_data)
#     204         if vmax is None:
#     205             if robust:
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     319         # Fast, but not safe for subclasses of ndarray, or object arrays,
#     320         # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 321         res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     322         if np.isnan(res).any():
#     323             warnings.warn("All-NaN slice encountered", RuntimeWarning,
#
# ValueError: zero-size array to reduction operation fmin which has no identity

# %%
#Correlation matrix of df
corr_mat=df.corr()
plt.subplots(figsize=(15, 10))
sns.heatmap(corr_mat, vmax=.5, cmap="jet");

# %%
#The above heatmap must be symmetric so i choose variables whose relativity is bigger than 0.75 from the upper triangular matrix (heatmap)
upper_trian=corr_mat.where(np.triu(np.ones(corr_mat.shape),k=0).astype(np.bool))
high_relation=[column for column in upper_trian.columns if any (upper_trian[column]>=0.75)]
print(high_relation)
# Out:
# ['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
#SalePrice correlation matrix
k = 30 #number of variables 
plt.figure(figsize = (25,15))
cols = corr_mat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df[cols].values.T)
#label's size
sns.set(font_scale=1.1)
hm = sns.heatmap(cm,cmap='PiYG', annot=True, fmt='.2f', annot_kws={'size': 9}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()
