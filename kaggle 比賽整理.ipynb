# %% [markdown]
# # 目前kaggle上正在進行中的比賽 (https://www.kaggle.com/competitions)
# ## 我稍微整理如下，共有19個，如果你看到這行，請往下滑到最後

# %% [markdown]
# ### 1.	惡意言論檢測
# 多個語言，英文表示，用tpu，dataset wiki 上的評論
# Jigsaw Multilingual Toxic Comment Classification
# Use TPUs to identify toxicity comments across multiple languagesFeatured • 19 days to go • Code Competition • 1212 Teams
# $50,000
#
# ### 2.	Walmart的銷售預測 (銷售額
# M5 Forecasting - Accuracy
# Estimate the unit sales of Walmart retail goodsFeatured • a month to go • 4644 Teams
# $50,000
#
# ### 3. Walmart的銷售預測 (銷量分布
# M5 Forecasting - Uncertainty
#  Estimate the uncertainty distribution of Walmart unit sales.Featured • a month to go • 553 Teams
# $50,000
#
# ### 4. 黑色素瘤分類
# SIIM-ISIC Melanoma Classification
# Identify melanoma in lesion imagesFeatured • 2 months to go • 472 Teams
# $30,000
#
# ### 5. 從腦部MRI資料預測表現及年齡
# TReNDS Neuroimaging
# Multiscanner normative age and assessments prediction with brain function, structure, and connectivityResearch • a month to go • 555 Teams
# $25,000
#
# ### 6. 偵測隱藏在圖像中的秘密數據
# ALASKA2 Image Steganalysis
# Detect secret data hidden within digital imagesResearch • 2 months to go • 443 Teams
# $25,000
#
# ### 7. 用Gleason 評分系統評估前列腺癌
# Prostate cANcer graDe Assessment (PANDA) Challenge
# Prostate cancer diagnosis using the Gleason grading systemFeatured • 2 months to go • Code Competition • 510 Teams
# $25,000
#
# ### 8. 從推特上的推文上情感標籤
# Tweet Sentiment Extraction
# Extract support phrases for sentiment labelsFeatured • 13 days to go • Code Competition • 1742 Teams
# $15,000
#
# ### 9. 圖像辨識小麥的數量與大小
# Global Wheat Detection
# Can you help identify wheat heads using image analysis?Research • 2 months to go • Code Competition • 668 Teams
# $15,000
#
# ### 10. 從照片集中挑選編列出"有趣的”組合(像放成投影片
# “有趣的”的標準: https://reurl.cc/0onLRo
# Hash Code Archive - Photo Slideshow Optimization
# Optimizing a photo album from Hash Code 2019Playground • 2 months to go • Code Competition • 33 Teams
# Knowledge
#
# ### 11. 檢測各種複雜圖像中的物體 ( 標示標籤並框出該物體的大致範圍 )
# Open Images Object Detection RVC 2020 edition
# Detect objects in varied and complex imagesPlayground • 2 months to go • 17 Teams
# Knowledge
#
# ### 12. 檢測各種複雜圖像中的物體 ( 標示該物體的精確邊界範圍 )
# Open Images Instance Segmentation RVC 2020 edition
# Outline segmentation masks of objects in imagesPlayground • 2 months to go • 3 Teams
# Knowledge
#
# ### 13. 預測下個月每個產品和商店的總銷售額
# Predict Future Sales
# Final project for "How to win a data science competition" Coursera coursePlayground • 7 months to go • 7143 Teams
# Kudos
#
# ### 14. 鐵達尼號存活預測 (老師說老哏了不要選
# Titanic: Machine Learning from Disaster
# Start here! Predict survival on the Titanic and get familiar with ML basicsGetting Started • Ongoing • 23425 Teams
# Knowledge
#
# ### 15. 房價預測
# House Prices: Advanced Regression Techniques
# Predict sales prices and practice feature engineering, RFs, and gradient boostingGetting Started • Ongoing • 5352 Teams
# Knowledge
#
# ### 16. mnist的手寫數字辨識 (老師說老哏了不要選
# Digit Recognizer
# Learn computer vision fundamentals with the famous MNIST dataGetting Started • Ongoing • 3210 Teams
# Knowledge
#
# ### 17. NLP(自然語言處理) 推特推文判斷是否為真實災害
# Real or Not? NLP with Disaster Tweets
# Predict which Tweets are about real disasters and which ones are notGetting Started • Ongoing • 1693 Teams
# Kudos
#
# ### 18. 玩類似五子棋的遊戲(?，跟其他人對抗 (沒有dataset, RL?
# Connect X
# Connect your checkers in a row before your opponent!Getting Started • Ongoing • Simulation Competition • 390 Teams
#
# ### 19. 玩遊戲，收集鹽礦 (沒有dataset, RL?
# Halite by Two Sigma
# Collect the most halite during your match in spaceFeatured • a month to go • Simulation Competition
# Kudos

# %% [markdown]
# ## 大概是這些，大家看了之後可以在fb留言想要的編號(大概1~3個
# ## 或是有什麼想法可以提出來跟大家討論討論~
